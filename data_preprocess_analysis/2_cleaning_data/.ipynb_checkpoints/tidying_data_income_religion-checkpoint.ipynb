# %%
import pandas as pd
import numpy as np
# %config IPCompleter.greedy=True

# %% [markdown]
# ### Câu 1: Pew Research Center
# Cho dữ liệu: pew-raw.csv. Bộ dữ liệu này khám phá mối quan hệ giữa thu nhập và tôn giáo (income & religion)
# * Đọc dữ liệu
# * Xem xét vấn đề về dữ liệu cần khắc phục
# * Chuẩn lại dữ liệu để khắc phục vấn dề trên

# %%
pew_data = pd.read_csv("data/pew-raw.csv")

# %%
pew_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
# religion    10 non-null object
#  <$10k      10 non-null int64
#  $10-20k    10 non-null int64
# $20-30k     10 non-null int64
# $30-40k     10 non-null int64
#  $40-50k    10 non-null int64
# $50-75k     10 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 640.0+ bytes

# %%
pew_data = pew_data.rename(columns={" <$10k": "<$10k", " $10-20k": "$10-20k", " $40-50k": "$40-50k"})

# %%
pew_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 7 columns):
# religion    10 non-null object
# <$10k       10 non-null int64
# $10-20k     10 non-null int64
# $20-30k     10 non-null int64
# $30-40k     10 non-null int64
# $40-50k     10 non-null int64
# $50-75k     10 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 640.0+ bytes

# %% [markdown]
# ### Cột <$10k, $10-20k, $20-30k, $30-40k, $40-50k, $50-75k chứa giá trị thay vì biến

# %%
#new_pew = pd.melt(frame = pew_data, id_vars = "religion", value_vars = ["<$10k", "$10-20k", "$20-30k", "$30-40k", "$40-50k","$50-75k"], var_name = "income")
new_pew = pd.melt(frame = pew_data, id_vars = "religion", var_name = "income", value_name = "count")

# %%
new_pew
# Out:
#                     religion   income  count
# 0                   Agnostic    <$10k     27
# 1                    Atheist    <$10k     12
# 2                   Buddhist    <$10k     27
# 3                   Catholic    <$10k    418
# 4          Dont know/refused    <$10k     15
# 5          Evangelical Prot     <$10k    575
# 6                     Hindu     <$10k      1
# 7   Historically Black Prot     <$10k    228
# 8          Jehovahs Witness     <$10k     20
# 9                    Jewish     <$10k     19
# 10                  Agnostic  $10-20k     34
# 11                   Atheist  $10-20k     27
# 12                  Buddhist  $10-20k     21
# 13                  Catholic  $10-20k    617
# 14         Dont know/refused  $10-20k     14
# 15         Evangelical Prot   $10-20k    869
# 16                    Hindu   $10-20k      9
# 17  Historically Black Prot   $10-20k    244
# 18         Jehovahs Witness   $10-20k     27
# 19                   Jewish   $10-20k     19
# ...
