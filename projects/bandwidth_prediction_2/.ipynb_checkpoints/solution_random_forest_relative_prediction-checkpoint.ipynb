# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
import lib as lib

# %% [markdown]
# ### Solution 3:
# We use random forest algorithm to predict max user and bandwidth independently<br>
# The first model is used to predict maxUser  base on data: **"ZONE_CODE", "HOUR_ID", "DATE_IN_WEEK", "DAY_SHIFT"** <br>
# The second model is used to predict bandwidth base on data: **MAX_USER** <br>
# Comebine these two models to predict maxUser and bandwidth on **test_id.csv**

# %%
dataset = pd.read_csv("data/clean_dataset.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35544 entries, 0 to 35543
# Data columns (total 9 columns):
# Unnamed: 0         35544 non-null int64
# UPDATE_TIME        35544 non-null int64
# ZONE_CODE          35544 non-null int64
# HOUR_ID            35544 non-null int64
# BANDWIDTH_TOTAL    35544 non-null float64
# MAX_USER           35544 non-null float64
# DATE_IN_MONTH      35544 non-null int64
# DATE_IN_WEEK       35544 non-null int64
# DAY_SHIFT          35544 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 2.4 MB

# %%
dataset.head(10)
# Out:
#    Unnamed: 0  UPDATE_TIME  ZONE_CODE  HOUR_ID  BANDWIDTH_TOTAL  MAX_USER  \
# 0           0   1506816000          1        0     16096.710313  212415.0
# 1           1   1506816000          1        1      9374.207907  166362.0
# 2           2   1506816000          1        2      5606.225750  146370.0
# 3           3   1506816000          1        3      4155.654661  141270.0
# 4           4   1506816000          1        4      3253.978594  139689.0
# 5           5   1506816000          1        5      4310.774522  165342.0
# 6           6   1506816000          1        6     10015.599874  221901.0
# 7           7   1506816000          1        7     19780.995631  302736.0
# 8           8   1506816000          1        8     24344.875025  336600.0
# 9           9   1506816000          1        9     28651.427689  356235.0
#
#    DATE_IN_MONTH  DATE_IN_WEEK  DAY_SHIFT
# 0              1             6          0
# 1              1             6          0
# 2              1             6          0
# 3              1             6          0
# 4              1             6          0
# 5              1             6          0
# 6              1             6          0
# 7              1             6          0
# 8              1             6          1
# 9              1             6          1

# %%
dataset.corr()
# Out:
#                  Unnamed: 0  UPDATE_TIME  ZONE_CODE   HOUR_ID  \
# Unnamed: 0         1.000000     0.999740   0.032327  0.002138
# UPDATE_TIME        0.999740     1.000000   0.032960  0.001460
# ZONE_CODE          0.032327     0.032960   1.000000  0.000041
# HOUR_ID            0.002138     0.001460   0.000041  1.000000
# BANDWIDTH_TOTAL    0.233774     0.233044  -0.611186  0.313592
# MAX_USER           0.154339     0.154116  -0.755793  0.181726
# DATE_IN_MONTH     -0.007666    -0.006745   0.008337 -0.000790
# DATE_IN_WEEK       0.004118     0.004290  -0.001165  0.000046
# DAY_SHIFT          0.001711     0.001073   0.000036  0.943551
#
#                  BANDWIDTH_TOTAL  MAX_USER  DATE_IN_MONTH  DATE_IN_WEEK  \
# Unnamed: 0              0.233774  0.154339      -0.007666      0.004118
# UPDATE_TIME             0.233044  0.154116      -0.006745      0.004290
# ZONE_CODE              -0.611186 -0.755793       0.008337     -0.001165
# HOUR_ID                 0.313592  0.181726      -0.000790      0.000046
# BANDWIDTH_TOTAL         1.000000  0.925587       0.003470      0.035023
# MAX_USER                0.925587  1.000000       0.008498      0.002566
# DATE_IN_MONTH           0.003470  0.008498       1.000000     -0.017459
# DATE_IN_WEEK            0.035023  0.002566      -0.017459      1.000000
# DAY_SHIFT               0.309379  0.183248      -0.000486     -0.000120
#
#                  DAY_SHIFT
# Unnamed: 0        0.001711
# UPDATE_TIME       0.001073
# ZONE_CODE         0.000036
# HOUR_ID           0.943551
# BANDWIDTH_TOTAL   0.309379
# MAX_USER          0.183248
# DATE_IN_MONTH    -0.000486
# DATE_IN_WEEK     -0.000120
# DAY_SHIFT         1.000000

# %%
#data = dataset[['DATE_IN_MONTH', 'ZONE_CODE', 'HOUR_ID']]
data = dataset[['ZONE_CODE', 'HOUR_ID', 'DATE_IN_WEEK', "DAY_SHIFT"]]
bandwidth_total = dataset.BANDWIDTH_TOTAL
max_user = dataset.MAX_USER

# %%
#x_train, x_test, y_train, y_test = train_test_split(data, max_user,test_size=0.3)
#x_train_max_user, x_test_max_user, y_train_max_user, y_test_max_user = train_test_split(data, max_user,test_size=0.3)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model_maxUser = RandomForestRegressor(n_estimators = 100, max_features='auto')
model_maxUser.fit(data, max_user)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
#predict_max_user = model_maxUser.predict(data)

# %%
x_train_maxuser, x_test_maxuser, y_train_bandwidth, y_test_bandwidth = train_test_split(pd.DataFrame(max_user), bandwidth_total, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
list_k = []
list_acc = []
for k in range(2,200):
    list_k.append(k)
    neigh = KNeighborsRegressor(n_neighbors = k, weights='uniform', algorithm='auto')
    neigh.fit(x_train_maxuser,  y_train_bandwidth)
    y_pred_banwidth = neigh.predict(x_test_maxuser)
    acc = r2_score(y_test_bandwidth, y_pred_banwidth)
    list_acc.append(acc)
    print("The Accurcy is", acc * 100, "% for k-value", k)
index = list_acc.index(max(list_acc))
k = list_k[index]
print("\nThe optimal number of neighbors is %d with %f%%" % (k, list_acc[index]* 100))
# Out:
# The Accurcy is 85.0626906976518 % for k-value 2
# The Accurcy is 86.16486948394231 % for k-value 3
# The Accurcy is 87.00831744247003 % for k-value 4
# The Accurcy is 87.61839146351623 % for k-value 5
# The Accurcy is 88.0169925430141 % for k-value 6
# The Accurcy is 88.45383834815165 % for k-value 7
# The Accurcy is 88.53606057919914 % for k-value 8
# The Accurcy is 88.6088072245902 % for k-value 9
# The Accurcy is 88.72006847689838 % for k-value 10
# The Accurcy is 88.77996546935957 % for k-value 11
# The Accurcy is 88.84306442788188 % for k-value 12
# The Accurcy is 88.87018400336095 % for k-value 13
# The Accurcy is 88.90947616319455 % for k-value 14
# The Accurcy is 88.98275796691978 % for k-value 15
# The Accurcy is 88.95390655240898 % for k-value 16
# The Accurcy is 89.02892464332929 % for k-value 17
# The Accurcy is 89.03600776565597 % for k-value 18
# The Accurcy is 89.08538345568101 % for k-value 19
# The Accurcy is 89.0856088630598 % for k-value 20
# The Accurcy is 89.11769738578553 % for k-value 21
# The Accurcy is 89.15995750250954 % for k-value 22
# The Accurcy is 89.197631313793 % for k-value 23
# The Accurcy is 89.21941495755316 % for k-value 24
# The Accurcy is 89.2295900030672 % for k-value 25
# The Accurcy is 89.23808768141328 % for k-value 26
# The Accurcy is 89.25729245498957 % for k-value 27
# The Accurcy is 89.25065250899618 % for k-value 28
# The Accurcy is 89.25334386455881 % for k-value 29
# The Accurcy is 89.24548646572326 % for k-value 30
# The Accurcy is 89.25252169682048 % for k-value 31
# The Accurcy is 89.2732695934817 % for k-value 32
# The Accurcy is 89.25805886844951 % for k-value 33
# The Accurcy is 89.25163608929432 % for k-value 34
# The Accurcy is 89.30337237411537 % for k-value 35
# The Accurcy is 89.3025223679048 % for k-value 36
# The Accurcy is 89.30578661707203 % for k-value 37
# The Accurcy is 89.30767055685529 % for k-value 38
# The Accurcy is 89.30597188319769 % for k-value 39
# The Accurcy is 89.31873385685641 % for k-value 40
# The Accurcy is 89.31559222284918 % for k-value 41
# The Accurcy is 89.31818094553888 % for k-value 42
# The Accurcy is 89.3171978796684 % for k-value 43
# The Accurcy is 89.3114051493314 % for k-value 44
# The Accurcy is 89.27743869885758 % for k-value 45
# The Accurcy is 89.26102726625244 % for k-value 46
# The Accurcy is 89.24926285295392 % for k-value 47
# The Accurcy is 89.27586773117326 % for k-value 48
# The Accurcy is 89.2795457300495 % for k-value 49
# The Accurcy is 89.28981058872323 % for k-value 50
# The Accurcy is 89.29372941864276 % for k-value 51
# The Accurcy is 89.29278106662713 % for k-value 52
# The Accurcy is 89.27313939339759 % for k-value 53
# The Accurcy is 89.271171102319 % for k-value 54
# The Accurcy is 89.26671334160996 % for k-value 55
# The Accurcy is 89.26556355387217 % for k-value 56
# The Accurcy is 89.25993625771956 % for k-value 57
# The Accurcy is 89.2608603383501 % for k-value 58
# The Accurcy is 89.26664468624924 % for k-value 59
# The Accurcy is 89.26541481997812 % for k-value 60
# The Accurcy is 89.27134014172842 % for k-value 61
# The Accurcy is 89.25596162536263 % for k-value 62
# The Accurcy is 89.25452811698119 % for k-value 63
# The Accurcy is 89.26026344757292 % for k-value 64
# The Accurcy is 89.25991437918816 % for k-value 65
# The Accurcy is 89.27233889027777 % for k-value 66
# The Accurcy is 89.26885732379597 % for k-value 67
# The Accurcy is 89.26439509909525 % for k-value 68
# The Accurcy is 89.28370601864435 % for k-value 69
# The Accurcy is 89.2958360894045 % for k-value 70
# The Accurcy is 89.28622874513236 % for k-value 71
# The Accurcy is 89.2901688188054 % for k-value 72
# The Accurcy is 89.2845234931178 % for k-value 73
# The Accurcy is 89.29159694702197 % for k-value 74
# The Accurcy is 89.28421868428147 % for k-value 75
# The Accurcy is 89.29292545337863 % for k-value 76
# The Accurcy is 89.29218528971313 % for k-value 77
# The Accurcy is 89.29187723052372 % for k-value 78
# The Accurcy is 89.28944863800585 % for k-value 79
# The Accurcy is 89.29148042873275 % for k-value 80
# The Accurcy is 89.2913090727981 % for k-value 81
# The Accurcy is 89.28315237459941 % for k-value 82
# The Accurcy is 89.27437832648312 % for k-value 83
# The Accurcy is 89.2734965545986 % for k-value 84
# The Accurcy is 89.2747570614174 % for k-value 85
# The Accurcy is 89.27588254670513 % for k-value 86
# The Accurcy is 89.27208848255958 % for k-value 87
# The Accurcy is 89.26780437759474 % for k-value 88
# The Accurcy is 89.26813821157768 % for k-value 89
# The Accurcy is 89.26700353938239 % for k-value 90
# The Accurcy is 89.26145159880285 % for k-value 91
# The Accurcy is 89.25335883596787 % for k-value 92
# The Accurcy is 89.25465533538464 % for k-value 93
# The Accurcy is 89.2579847041911 % for k-value 94
# The Accurcy is 89.26158158898063 % for k-value 95
# The Accurcy is 89.25857899233812 % for k-value 96
# The Accurcy is 89.26464110001005 % for k-value 97
# The Accurcy is 89.26999236365168 % for k-value 98
# The Accurcy is 89.2764837395342 % for k-value 99
# The Accurcy is 89.27070151030567 % for k-value 100
# The Accurcy is 89.26122808067014 % for k-value 101
# The Accurcy is 89.25419291545683 % for k-value 102
# The Accurcy is 89.25160299924474 % for k-value 103
# The Accurcy is 89.25050332297772 % for k-value 104
# The Accurcy is 89.25023927710095 % for k-value 105
# The Accurcy is 89.2452467736347 % for k-value 106
# The Accurcy is 89.24298962572966 % for k-value 107
# The Accurcy is 89.24374603740257 % for k-value 108
# The Accurcy is 89.23849721082149 % for k-value 109
# The Accurcy is 89.23866041296277 % for k-value 110
# The Accurcy is 89.23425092425074 % for k-value 111
# The Accurcy is 89.2269038101818 % for k-value 112
# The Accurcy is 89.22864041262137 % for k-value 113
# The Accurcy is 89.22300165281204 % for k-value 114
# The Accurcy is 89.21742710323282 % for k-value 115
# The Accurcy is 89.21996372407452 % for k-value 116
# The Accurcy is 89.2171966856798 % for k-value 117
# The Accurcy is 89.20719657872371 % for k-value 118
# The Accurcy is 89.2027292440817 % for k-value 119
# The Accurcy is 89.20359715858976 % for k-value 120
# The Accurcy is 89.20111381045021 % for k-value 121
# The Accurcy is 89.19765209293466 % for k-value 122
# The Accurcy is 89.19634944929949 % for k-value 123
# The Accurcy is 89.19097208854481 % for k-value 124
# The Accurcy is 89.19718423780374 % for k-value 125
# The Accurcy is 89.19955422034431 % for k-value 126
# The Accurcy is 89.19922724466193 % for k-value 127
# The Accurcy is 89.19696809455586 % for k-value 128
# The Accurcy is 89.18565250152642 % for k-value 129
# The Accurcy is 89.17904615829494 % for k-value 130
# The Accurcy is 89.17718226934593 % for k-value 131
# The Accurcy is 89.18093455326941 % for k-value 132
# The Accurcy is 89.18036700724782 % for k-value 133
# The Accurcy is 89.17645685104937 % for k-value 134
# The Accurcy is 89.17814210087657 % for k-value 135
# The Accurcy is 89.17061362105305 % for k-value 136
# The Accurcy is 89.16916188131779 % for k-value 137
# The Accurcy is 89.1658185530808 % for k-value 138
# The Accurcy is 89.16707868511928 % for k-value 139
# The Accurcy is 89.16491614869348 % for k-value 140
# The Accurcy is 89.16731924423473 % for k-value 141
# The Accurcy is 89.16274835349725 % for k-value 142
# The Accurcy is 89.15616059127004 % for k-value 143
# The Accurcy is 89.15363466185951 % for k-value 144
# The Accurcy is 89.15367418759196 % for k-value 145
# The Accurcy is 89.15639984464076 % for k-value 146
# The Accurcy is 89.1557316798318 % for k-value 147
# The Accurcy is 89.1574566291935 % for k-value 148
# The Accurcy is 89.15166460522708 % for k-value 149
# The Accurcy is 89.14208316467361 % for k-value 150
# The Accurcy is 89.14473456861872 % for k-value 151
# The Accurcy is 89.1417456241122 % for k-value 152
# The Accurcy is 89.13391204433965 % for k-value 153
# The Accurcy is 89.12588378551884 % for k-value 154
# The Accurcy is 89.12581058682387 % for k-value 155
# The Accurcy is 89.123670431303 % for k-value 156
# The Accurcy is 89.12321701121189 % for k-value 157
# The Accurcy is 89.11985654079663 % for k-value 158

# %%
model_bandwidth = KNeighborsRegressor(n_neighbors = k, weights='uniform', algorithm='auto')
model_bandwidth.fit(pd.DataFrame(max_user),  bandwidth_total)

# %%
raw_test_data = pd.read_csv("data/test_id.csv")

# %%
raw_test_data.head()

# %%
raw_test_data.ZONE_CODE = raw_test_data.ZONE_CODE.map({'ZONE01' : 1, 'ZONE03' : 3, 'ZONE02' : 2})
raw_test_data['DATE_IN_MONTH'] =  raw_test_data.UPDATE_TIME.map(lib.get_date_in_month).astype('int32')
raw_test_data['DATE_IN_WEEK'] =  raw_test_data.UPDATE_TIME.map(lib.get_date_in_week).astype('int32')
raw_test_data['DAY_SHIFT'] =  raw_test_data.HOUR_ID.map(lib.hour_to_shift).astype('int32')
raw_test_data.UPDATE_TIME = raw_test_data.UPDATE_TIME.map(lib.convert_datetime_to_timestamp).astype('int32')

# %%
raw_test_data.head()

# %%
test_data = raw_test_data[['ZONE_CODE', 'HOUR_ID', 'DATE_IN_WEEK', "DAY_SHIFT"]]

# %%
test_maxUser = model_maxUser.predict(test_data)

# %%
test_bandwidth = model_bandwidth.predict(pd.DataFrame(test_maxUser))

# %%
test_bandwidth = np.around(test_bandwidth, decimals=2)
test_bandwidth

# %%
test_maxUser

# %%
test_maxUser = np.round(test_maxUser)
test_maxUser

# %%
final_test_data = pd.DataFrame({'id': raw_test_data['id'], 'bandwidth': test_bandwidth,"max_user": test_maxUser})

# %%
final_test_data['label'] = final_test_data[['bandwidth', 'max_user']].apply(lambda x: '{} {}'.format(x[0],x[1]), axis=1)

# %%
export_test_data = final_test_data[['id', 'label']]

# %%
export_test_data.to_csv("data/solution_random_forest_relative_prediction.csv", index=False)

# %%
export_test_data.head()
